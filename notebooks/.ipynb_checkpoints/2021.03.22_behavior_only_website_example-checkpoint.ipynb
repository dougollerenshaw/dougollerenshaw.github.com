# %% [markdown]
# # Example behavior session
# The following example shows how to access behavioral data for a given mouse across sessions
#
# The following assumes that the AllenSDK has been installed in your environment. If not, run:
#
#     pip install allensdk

# %% [markdown]
# ## imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)

import allensdk.brain_observatory.behavior.behavior_project_cache as bpc

# %%
# %matplotlib notebook

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## load cache, get behavior session table

# %%
# choose a location on your file system to cache NWB files as they are loaded:
my_cache_dir = '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/allensdk_visualbehavior_cache'

bc = bpc.VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=my_cache_dir)
          
behavior_session_table = bc.get_behavior_session_table()

# %% [markdown]
# ## view a sample of the behavior session table

# %%
behavior_session_table.sample(10)
# Out:
#                     equipment_name  \
# behavior_session_id
# 977746260               BEH.D-Box6
# 924472023                   MESO.1
# 792654939                    BEH.G
# 1038132332              BEH.G-Box1
# 972681015                  CAM2P.5
# 959681045                   MESO.1
# 915609195               BEH.G-Box3
# 978678310               BEH.D-Box5
# 841271104                  CAM2P.4
# 895877651               BEH.D-Box2
#
#                                                          full_genotype  \
# behavior_session_id
# 977746260                Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 924472023            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 792654939            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-G...
# 1038132332               Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 972681015            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-G...
# 959681045                Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 915609195                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 978678310                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 841271104            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-G...
# 895877651            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-G...
#
#                      mouse_id               reporter_line  \
# behavior_session_id
# 977746260              476970  Ai148(TIT2L-GC6f-ICL-tTA2)
# 924472023              453911          Ai93(TITL-GCaMP6f)
# 792654939              423606          Ai94(TITL-GCaMP6s)
# 1038132332             523927  Ai148(TIT2L-GC6f-ICL-tTA2)
# 972681015              479426          Ai94(TITL-GCaMP6s)
# 959681045              457841  Ai148(TIT2L-GC6f-ICL-tTA2)
# 915609195              453991  Ai148(TIT2L-GC6f-ICL-tTA2)
# 978678310              486737  Ai148(TIT2L-GC6f-ICL-tTA2)
# 841271104              442709          Ai94(TITL-GCaMP6s)
# 895877651              457766          Ai94(TITL-GCaMP6s)
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 977746260                             [Sst-IRES-Cre]   M        159.0
# 924472023            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        188.0
# 792654939            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         86.0
# 1038132332                            [Vip-IRES-Cre]   F        129.0
# 972681015            [Slc17a7-IRES2-Cre, Camk2a-tTA]   F        136.0
# 959681045                             [Sst-IRES-Cre]   F        218.0
# 915609195                             [Vip-IRES-Cre]   M        174.0
# 978678310                             [Vip-IRES-Cre]   F        110.0
# 841271104            [Slc17a7-IRES2-Cre, Camk2a-tTA]   F         94.0
# 895877651            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        121.0
#
#                                            session_type           cre_line  \
# behavior_session_id
# 977746260            TRAINING_5_images_B_handoff_lapsed       Sst-IRES-Cre
# 924472023                              OPHYS_1_images_A  Slc17a7-IRES2-Cre
# 792654939               TRAINING_3_images_A_10uL_reward  Slc17a7-IRES2-Cre
# 1038132332                 TRAINING_5_images_A_epilogue       Vip-IRES-Cre
# 972681015                      OPHYS_2_images_A_passive  Slc17a7-IRES2-Cre
# 959681045                              OPHYS_6_images_B       Sst-IRES-Cre
# 915609195             TRAINING_5_images_A_handoff_ready       Vip-IRES-Cre
# 978678310               TRAINING_3_images_B_10uL_reward       Vip-IRES-Cre
# 841271104                  OPHYS_0_images_A_habituation  Slc17a7-IRES2-Cre
# 895877651                  TRAINING_4_images_A_training  Slc17a7-IRES2-Cre
#
#                     indicator  session_number  \
# behavior_session_id
# 977746260             GCaMP6f             NaN
# 924472023             GCaMP6f             1.0
# 792654939             GCaMP6s             NaN
# 1038132332            GCaMP6f             NaN
# 972681015             GCaMP6s             2.0
# 959681045             GCaMP6f             6.0
# 915609195             GCaMP6f             NaN
# 978678310             GCaMP6f             NaN
# 841271104             GCaMP6s             0.0
# 895877651             GCaMP6s             NaN
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 977746260                                          8
# 924472023                                          4
# 792654939                                          0
# 1038132332                                         3
# 972681015                                          0
# 959681045                                          0
# 915609195                                          5
# 978678310                                          0
# 841271104                                          1
# 895877651                                         12
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 977746260                                     NaN
# 924472023                                    17.0
# 792654939                                     NaN
# 1038132332                                    NaN
# 972681015                                     5.0
# 959681045                                     2.0
# 915609195                                     NaN
# 978678310                                     NaN
# 841271104                                     1.0
# 895877651                                     NaN
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# behavior_session_id
# 977746260                                       0               NaN
# 924472023                                      18               NaN
# 792654939                                       0               NaN
# 1038132332                                      0               NaN
# 972681015                                       1               NaN
# 959681045                                       7       959458018.0
# 915609195                                       0               NaN
# 978678310                                       0               NaN
# 841271104                                       0               NaN
# 895877651                                       0               NaN
#
#                                                    ophys_experiment_id  \
# behavior_session_id
# 977746260                                                          NaN
# 924472023                                                          NaN
# 792654939                                                          NaN
# 1038132332                                                         NaN
# 972681015                                                          NaN
# 959681045            [960410023, 960410026, 960410028, 960410038, 9...
# 915609195                                                          NaN
# 978678310                                                          NaN
# 841271104                                                          NaN
# 895877651                                                          NaN
#
#                                                     ophys_container_id  \
# behavior_session_id
# 977746260                                                          NaN
# 924472023                                                          NaN
# 792654939                                                          NaN
# 1038132332                                                         NaN
# 972681015                                                          NaN
# 959681045            [1018028339, 1018028342, 1018028345, 101802835...
# 915609195                                                          NaN
# 978678310                                                          NaN
# 841271104                                                          NaN
# 895877651                                                          NaN
#
#                                  project_code      date_of_acquisition  \
# behavior_session_id
# 977746260                                 NaN  2019-11-06 12:25:07.008
# 924472023                                 NaN  2019-08-15 08:28:25.944
# 792654939                                 NaN  2018-12-10 13:16:02.765
# 1038132332                                NaN  2020-07-23 13:13:25.926
# 972681015                                 NaN  2019-10-25 09:04:07.711
# 959681045            VisualBehaviorMultiscope  2019-10-02 09:22:55.956
# 915609195                                 NaN  2019-08-01 11:42:09.969
# 978678310                                 NaN  2019-11-08 10:27:14.505
# 841271104                                 NaN  2019-03-25 10:32:43.224
# 895877651                                 NaN  2019-06-27 12:07:00.057
#
#                           file_id
# behavior_session_id
# 977746260            1.081760e+09
# 924472023            1.081715e+09
# 792654939            1.081568e+09
# 1038132332           1.081778e+09
# 972681015            1.081760e+09
# 959681045                     NaN
# 915609195            1.081713e+09
# 978678310            1.081761e+09
# 841271104            1.085362e+09
# 895877651            1.081645e+09

# %% [markdown]
# ## randomly select one mouse

# %%
np.random.seed(5)
mouse_id = np.random.choice(behavior_session_table['mouse_id'].unique())
mouse_id
# Out:
# 445002

# %% [markdown]
# ## query the full behavior sessions table for all sessions that this mouse performed
# Note that this mouse has two `OPHYS_5_images_B_passive` sessions, the first taken in order (immediately after `OPHYS_4_images_B`), and second taken at the end of the sequence. The first `OPHYS_5_images_B_passive` does not have an `ophys_session_id` associated with it. This is likely due to that first session failing to meet quality control standards and being excluded from the dataset. The second `OPHYS_5_images_B_passive` was likely a retake, taken after the first was identified as having been failed.
#
# In general, ophys behavior sessions that do not have associated ophys_session_ids are sessions for which the ophys data has been removed do to failure to meet quality control standards.

# %%
this_mouse_table = behavior_session_table.query('mouse_id == @mouse_id')
# note that the following is functionally equivalent if you find the syntax easier to read: 
# this_mouse_table = behavior_session_table[behavior_session_table['mouse_id'] == mouse_id]
this_mouse_table
# Out:
#                     equipment_name  \
# behavior_session_id
# 837658854               BEH.B-Box3
# 838515247               BEH.B-Box1
# 839219841               BEH.B-Box1
# 839565422               BEH.B-Box1
# 839912316               BEH.B-Box1
# 840581827               BEH.B-Box1
# 841426832               BEH.B-Box1
# 841827774               BEH.B-Box1
# 842385277               BEH.B-Box1
# 842819933               BEH.B-Box1
# 843400453               BEH.B-Box1
# 844199758               BEH.B-Box1
# 844908261               BEH.B-Box1
# 845572044               BEH.B-Box1
# 846331423                  CAM2P.3
# 847036328                  CAM2P.3
# 847874940                  CAM2P.3
# 848613406                  CAM2P.3
# 849147676                  CAM2P.3
# 849651275                  CAM2P.3
# 850989832                  CAM2P.3
# 851773928                  CAM2P.3
# 852451567                  CAM2P.3
# 855200229                  CAM2P.3
#
#                                                          full_genotype  \
# behavior_session_id
# 837658854            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 838515247            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839219841            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839565422            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839912316            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 840581827            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 841426832            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 841827774            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 842385277            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 842819933            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 843400453            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 844199758            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 844908261            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 845572044            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 846331423            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 847036328            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 847874940            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 848613406            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 849147676            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 849651275            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 850989832            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 851773928            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 852451567            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 855200229            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
#
#                      mouse_id       reporter_line  \
# behavior_session_id
# 837658854              445002  Ai93(TITL-GCaMP6f)
# 838515247              445002  Ai93(TITL-GCaMP6f)
# 839219841              445002  Ai93(TITL-GCaMP6f)
# 839565422              445002  Ai93(TITL-GCaMP6f)
# 839912316              445002  Ai93(TITL-GCaMP6f)
# 840581827              445002  Ai93(TITL-GCaMP6f)
# 841426832              445002  Ai93(TITL-GCaMP6f)
# 841827774              445002  Ai93(TITL-GCaMP6f)
# 842385277              445002  Ai93(TITL-GCaMP6f)
# 842819933              445002  Ai93(TITL-GCaMP6f)
# 843400453              445002  Ai93(TITL-GCaMP6f)
# 844199758              445002  Ai93(TITL-GCaMP6f)
# 844908261              445002  Ai93(TITL-GCaMP6f)
# 845572044              445002  Ai93(TITL-GCaMP6f)
# 846331423              445002  Ai93(TITL-GCaMP6f)
# 847036328              445002  Ai93(TITL-GCaMP6f)
# 847874940              445002  Ai93(TITL-GCaMP6f)
# 848613406              445002  Ai93(TITL-GCaMP6f)
# 849147676              445002  Ai93(TITL-GCaMP6f)
# 849651275              445002  Ai93(TITL-GCaMP6f)
# 850989832              445002  Ai93(TITL-GCaMP6f)
# 851773928              445002  Ai93(TITL-GCaMP6f)
# 852451567              445002  Ai93(TITL-GCaMP6f)
# 855200229              445002  Ai93(TITL-GCaMP6f)
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 837658854            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         72.0
# 838515247            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         75.0
# 839219841            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         76.0
# 839565422            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         77.0
# 839912316            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         78.0
# 840581827            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         79.0
# 841426832            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         82.0
# 841827774            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         83.0
# 842385277            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         84.0
# 842819933            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         85.0
# 843400453            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         86.0
# 844199758            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         89.0
# 844908261            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         90.0
# 845572044            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         91.0
# 846331423            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         92.0
# 847036328            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         93.0
# 847874940            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         96.0
# 848613406            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         97.0
# 849147676            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         98.0
# 849651275            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         99.0
# 850989832            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        100.0
# 851773928            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        103.0
# 852451567            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        104.0
# 855200229            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        110.0
#
#                                               session_type           cre_line  \
# behavior_session_id
# 837658854            TRAINING_0_gratings_autorewards_15min  Slc17a7-IRES2-Cre
# 838515247                              TRAINING_1_gratings  Slc17a7-IRES2-Cre
# 839219841                              TRAINING_1_gratings  Slc17a7-IRES2-Cre
# 839565422                              TRAINING_1_gratings  Slc17a7-IRES2-Cre
# 839912316                      TRAINING_2_gratings_flashed  Slc17a7-IRES2-Cre
# 840581827                      TRAINING_2_gratings_flashed  Slc17a7-IRES2-Cre
# 841426832                  TRAINING_3_images_A_10uL_reward  Slc17a7-IRES2-Cre
# 841827774                  TRAINING_3_images_A_10uL_reward  Slc17a7-IRES2-Cre
# 842385277                  TRAINING_3_images_A_10uL_reward  Slc17a7-IRES2-Cre
# 842819933                     TRAINING_4_images_A_training  Slc17a7-IRES2-Cre
# 843400453                     TRAINING_5_images_A_epilogue  Slc17a7-IRES2-Cre
# 844199758                TRAINING_5_images_A_handoff_ready  Slc17a7-IRES2-Cre
# 844908261                TRAINING_5_images_A_handoff_ready  Slc17a7-IRES2-Cre
# 845572044                TRAINING_5_images_A_handoff_ready  Slc17a7-IRES2-Cre
# 846331423                     OPHYS_0_images_A_habituation  Slc17a7-IRES2-Cre
# 847036328                     OPHYS_0_images_A_habituation  Slc17a7-IRES2-Cre
# 847874940                     OPHYS_0_images_A_habituation  Slc17a7-IRES2-Cre
# 848613406                                 OPHYS_1_images_A  Slc17a7-IRES2-Cre
# 849147676                         OPHYS_2_images_A_passive  Slc17a7-IRES2-Cre
# 849651275                                 OPHYS_3_images_A  Slc17a7-IRES2-Cre
# 850989832                                 OPHYS_4_images_B  Slc17a7-IRES2-Cre
# 851773928                         OPHYS_5_images_B_passive  Slc17a7-IRES2-Cre
# 852451567                                 OPHYS_6_images_B  Slc17a7-IRES2-Cre
# 855200229                         OPHYS_5_images_B_passive  Slc17a7-IRES2-Cre
#
#                     indicator  session_number  \
# behavior_session_id
# 837658854             GCaMP6f             NaN
# 838515247             GCaMP6f             NaN
# 839219841             GCaMP6f             NaN
# 839565422             GCaMP6f             NaN
# 839912316             GCaMP6f             NaN
# 840581827             GCaMP6f             NaN
# 841426832             GCaMP6f             NaN
# 841827774             GCaMP6f             NaN
# 842385277             GCaMP6f             NaN
# 842819933             GCaMP6f             NaN
# 843400453             GCaMP6f             NaN
# 844199758             GCaMP6f             NaN
# 844908261             GCaMP6f             NaN
# 845572044             GCaMP6f             NaN
# 846331423             GCaMP6f             0.0
# 847036328             GCaMP6f             0.0
# 847874940             GCaMP6f             0.0
# 848613406             GCaMP6f             1.0
# 849147676             GCaMP6f             2.0
# 849651275             GCaMP6f             3.0
# 850989832             GCaMP6f             4.0
# 851773928             GCaMP6f             5.0
# 852451567             GCaMP6f             6.0
# 855200229             GCaMP6f             5.0
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 837658854                                          0
# 838515247                                          0
# 839219841                                          1
# 839565422                                          2
# 839912316                                          0
# 840581827                                          1
# 841426832                                          0
# 841827774                                          1
# 842385277                                          2
# 842819933                                          0
# 843400453                                          0
# 844199758                                          0
# 844908261                                          1
# 845572044                                          2
# 846331423                                          0
# 847036328                                          1
# 847874940                                          2
# 848613406                                          0
# 849147676                                          0
# 849651275                                          0
# 850989832                                          0
# 851773928                                          0
# 852451567                                          0
# 855200229                                          1
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 837658854                                     NaN
# 838515247                                     NaN
# 839219841                                     NaN
# 839565422                                     NaN
# 839912316                                     NaN
# 840581827                                     NaN
# 841426832                                     NaN
# 841827774                                     NaN
# 842385277                                     NaN
# 842819933                                     NaN
# 843400453                                     NaN
# 844199758                                     NaN
# 844908261                                     NaN
# 845572044                                     NaN
# 846331423                                     0.0
# 847036328                                     1.0
# 847874940                                     2.0
# 848613406                                     3.0
# 849147676                                     4.0
# 849651275                                     5.0
# 850989832                                     0.0
# 851773928                                     1.0
# 852451567                                     2.0
# 855200229                                     3.0
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# behavior_session_id
# 837658854                                       0               NaN
# 838515247                                       0               NaN
# 839219841                                       0               NaN
# 839565422                                       0               NaN
# 839912316                                       0               NaN
# 840581827                                       0               NaN
# 841426832                                       0               NaN
# 841827774                                       0               NaN
# 842385277                                       0               NaN
# 842819933                                       0               NaN
# 843400453                                       0               NaN
# 844199758                                       0               NaN
# 844908261                                       0               NaN
# 845572044                                       0               NaN
# 846331423                                       0               NaN
# 847036328                                       0               NaN
# 847874940                                       0               NaN
# 848613406                                       0       848264483.0
# 849147676                                       1       848894137.0
# 849651275                                       2       849597937.0
# 850989832                                       3       850959102.0
# 851773928                                       4               NaN
# 852451567                                       5       852326785.0
# 855200229                                       6       855083235.0
#
#                     ophys_experiment_id ophys_container_id    project_code  \
# behavior_session_id
# 837658854                           NaN                NaN             NaN
# 838515247                           NaN                NaN             NaN
# 839219841                           NaN                NaN             NaN
# 839565422                           NaN                NaN             NaN
# 839912316                           NaN                NaN             NaN
# 840581827                           NaN                NaN             NaN
# 841426832                           NaN                NaN             NaN
# 841827774                           NaN                NaN             NaN
# 842385277                           NaN                NaN             NaN
# 842819933                           NaN                NaN             NaN
# 843400453                           NaN                NaN             NaN
# 844199758                           NaN                NaN             NaN
# 844908261                           NaN                NaN             NaN
# 845572044                           NaN                NaN             NaN
# 846331423                           NaN                NaN             NaN
# 847036328                           NaN                NaN             NaN
# 847874940                           NaN                NaN             NaN
# 848613406                   [848697625]        [846215539]  VisualBehavior
# 849147676                   [849203565]        [846215539]  VisualBehavior
# 849651275                   [850479305]        [846215539]  VisualBehavior
# 850989832                   [851060467]        [846215539]  VisualBehavior
# 851773928                           NaN                NaN             NaN
# 852451567                   [852691524]        [846215539]  VisualBehavior
# 855200229                   [855582961]        [846215539]  VisualBehavior
#
#                          date_of_acquisition       file_id
# behavior_session_id
# 837658854            2019-03-15 14:49:24.015  1.085362e+09
# 838515247            2019-03-18 13:44:01.474  1.085362e+09
# 839219841            2019-03-19 12:50:12.068  1.085362e+09
# 839565422            2019-03-20 13:16:44.461  1.085362e+09
# 839912316            2019-03-21 12:54:25.388  1.081589e+09
# 840581827            2019-03-22 12:56:37.162  1.081589e+09
# 841426832            2019-03-25 13:33:53.275  1.081589e+09
# 841827774            2019-03-26 12:43:01.470  1.081590e+09
# 842385277            2019-03-27 12:13:04.923  1.081591e+09
# 842819933            2019-03-28 12:11:36.413  1.081591e+09
# 843400453            2019-03-29 13:03:16.029  1.081592e+09
# 844199758            2019-04-01 11:59:06.026  1.081591e+09
# 844908261            2019-04-02 12:34:16.170  1.081592e+09
# 845572044            2019-04-03 12:16:13.522  1.081592e+09
# 846331423            2019-04-04 13:13:13.399  1.085362e+09
# 847036328            2019-04-05 12:47:32.422  1.085362e+09
# 847874940            2019-04-08 13:27:21.095  1.085362e+09
# 848613406            2019-04-09 13:26:26.372           NaN
# 849147676            2019-04-10 13:34:39.264           NaN
# 849651275            2019-04-11 12:31:50.074           NaN
# 850989832            2019-04-12 13:30:27.946           NaN
# 851773928            2019-04-15 12:20:00.123  1.081596e+09
# 852451567            2019-04-16 12:24:46.804           NaN
# 855200229            2019-04-22 09:01:33.022           NaN

# %% [markdown]
# ## iterate over all sessions for this mouse, build a `behavior_session_dict` which will have one behavior session object for every session that this mouse performed, with the key being the `behavior_session_id`
# Note that this could take many minutes to complete

# %%
behavior_session_ids = this_mouse_table.index.values
behavior_session_dict = {}
for behavior_session_id in behavior_session_ids:
    behavior_session_dict[behavior_session_id] = bc.get_behavior_session(behavior_session_id)
# Out:
# behavior_session_837658854.nwb: 100%|██████████| 51.7M/51.7M [00:04<00:00, 11.4MMB/s]
# behavior_session_838515247.nwb: 100%|██████████| 66.9M/66.9M [00:06<00:00, 10.7MMB/s]
# behavior_session_839219841.nwb: 100%|██████████| 66.7M/66.7M [00:07<00:00, 8.98MMB/s]
# behavior_session_839565422.nwb: 100%|██████████| 66.7M/66.7M [00:07<00:00, 9.24MMB/s]
# behavior_session_839912316.nwb: 100%|██████████| 68.0M/68.0M [00:06<00:00, 10.7MMB/s]
# behavior_session_840581827.nwb: 100%|██████████| 68.0M/68.0M [00:06<00:00, 10.0MMB/s]
# behavior_session_841426832.nwb: 100%|██████████| 188M/188M [00:17<00:00, 10.6MMB/s]
# behavior_session_841827774.nwb: 100%|██████████| 188M/188M [00:14<00:00, 12.5MMB/s]
# behavior_session_842385277.nwb: 100%|██████████| 188M/188M [00:15<00:00, 12.4MMB/s]
# behavior_session_842819933.nwb: 100%|██████████| 188M/188M [00:35<00:00, 5.34MMB/s]
# behavior_session_843400453.nwb: 100%|██████████| 193M/193M [00:16<00:00, 11.5MMB/s]
# behavior_session_844199758.nwb: 100%|██████████| 193M/193M [00:15<00:00, 12.6MMB/s]
# behavior_session_844908261.nwb: 100%|██████████| 193M/193M [00:15<00:00, 12.5MMB/s]
# behavior_session_845572044.nwb: 100%|██████████| 193M/193M [00:15<00:00, 12.2MMB/s]
# behavior_session_846331423.nwb: 100%|██████████| 193M/193M [00:15<00:00, 12.1MMB/s]
# behavior_session_847036328.nwb: 100%|██████████| 193M/193M [00:15<00:00, 12.4MMB/s]
# behavior_session_847874940.nwb: 100%|██████████| 193M/193M [00:16<00:00, 11.6MMB/s]
# behavior_ophys_experiment_848697625.nwb: 100%|██████████| 819M/819M [01:05<00:00, 12.4MMB/s]
# behavior_ophys_experiment_849203565.nwb: 100%|██████████| 950M/950M [01:16<00:00, 12.4MMB/s]
# behavior_ophys_experiment_850479305.nwb: 100%|██████████| 898M/898M [01:10<00:00, 12.8MMB/s]
# behavior_ophys_experiment_851060467.nwb: 100%|██████████| 877M/877M [01:14<00:00, 11.7MMB/s]
# behavior_session_851773928.nwb: 100%|██████████| 192M/192M [00:16<00:00, 12.0MMB/s]
# behavior_ophys_experiment_852691524.nwb: 100%|██████████| 926M/926M [01:10<00:00, 13.1MMB/s]
# behavior_ophys_experiment_855582961.nwb: 100%|██████████| 1.04G/1.04G [01:23<00:00, 12.4MMB/s]

# %% [markdown]
# ## We can view all attributes of the behavior session object

# %%
[print(property) for property in dir(behavior_session_dict[behavior_session_ids[-1]]) if not property.startswith('_')];
# Out:
# LazyProperty
# api
# behavior_session_id
# cache_clear
# from_lims
# from_nwb_path
# get_performance_metrics
# get_reward_rate
# get_rolling_performance_df
# licks
# list_api_methods
# metadata
# raw_running_speed
# rewards
# running_speed
# stimulus_presentations
# stimulus_templates
# stimulus_timestamps
# task_parameters
# trials

# %% [markdown]
# ## Look at some of the attributes of the last 'handoff ready session'

# %%
behavior_session_id = this_mouse_table.query('session_type == "TRAINING_5_images_A_handoff_ready"').index[-1]
# note that the following is functionally equivalent if you find the syntax easier to read: 
# behavior_session_id = this_mouse_table[this_mouse_table['session_type'] == "TRAINING_5_images_A_handoff_ready"].index[-1]
dataset = behavior_session_dict[behavior_session_id]

# %% [markdown]
# ### stimuli

# %%
dataset.stimulus_presentations.sample(5)
# Out:
#                            duration  end_frame  image_index image_name  \
# stimulus_presentations_id
# 1831                       0.266874   100597.0            3      im061
# 3561                       0.250204   178639.0            0      im065
# 928                        0.250178    59862.0            1      im077
# 2008                       0.250219   108576.0            2      im066
# 1371                       0.250209    79843.0            3      im061
#
#                                                                    image_set  \
# stimulus_presentations_id
# 1831                       Natural_Images_Lum_Matched_set_training_2017.0...
# 3561                       Natural_Images_Lum_Matched_set_training_2017.0...
# 928                        Natural_Images_Lum_Matched_set_training_2017.0...
# 2008                       Natural_Images_Lum_Matched_set_training_2017.0...
# 1371                       Natural_Images_Lum_Matched_set_training_2017.0...
#
#                            index  omitted  start_frame   start_time  \
# stimulus_presentations_id
# 1831                        1831    False     100581.0  1677.756647
# 3561                        3561    False     178624.0  2979.581535
# 928                          928    False      59847.0   998.286934
# 2008                        2008    False     108561.0  1810.868245
# 1371                        1371    False      79828.0  1331.583043
#
#                              stop_time
# stimulus_presentations_id
# 1831                       1678.023521
# 3561                       2979.831739
# 928                         998.537112
# 2008                       1811.118465
# 1371                       1331.833252

# %% [markdown]
# ### licks

# %%
dataset.licks.sample(5)
# Out:
#        timestamps   frame
# 516    796.100719   47726
# 1307  1627.030794   97540
# 1593  1972.637248  118259
# 1025  1426.479280   85517
# 1442  1790.184232  107321

# %% [markdown]
# ### rewards

# %%
dataset.rewards.sample(5)
# Out:
#      volume   timestamps  autorewarded
# 86    0.007  1763.178257         False
# 105   0.007  2703.299877         False
# 74    0.007  1569.032139         False
# 35    0.007   919.904562         False
# 71    0.007  1533.569074         False

# %% [markdown]
# ### running data

# %%
dataset.running_speed.head()
# Out:
#    timestamps     speed
# 0    0.000000  0.010719
# 1    0.016554 -0.034077
# 2    0.033231 -0.079193
# 3    0.049912 -0.121338
# 4    0.067623 -0.156735

# %% [markdown]
# ### we can make a simple plot where we combine together running, licking and stimuli

# %% [markdown]
# #### First, add a column to the stimulus_presentations table that assigns a unique color to every stimulus

# %%
unique_stimuli = [stimulus for stimulus in dataset.stimulus_presentations['image_name'].unique()]
colormap = {image_name: sns.color_palette()[image_number] for image_number, image_name in enumerate(np.sort(unique_stimuli))}
dataset.stimulus_presentations['color'] = dataset.stimulus_presentations['image_name'].map(lambda image_name: colormap[image_name])

# %% [markdown]
# #### now make some simple plotting functions to plot these datastreams

# %%
def plot_running(ax, ti, tf):
    running_sample = dataset.running_speed.query('timestamps >= @ti and timestamps <= @tf')
    ax.plot(
        running_sample['timestamps'],
        running_sample['speed']
    )

def plot_licks(ax, ti, tf):
    licking_sample = dataset.licks.query('timestamps >= @ti and timestamps <= @tf')
    ax.plot(
        licking_sample['timestamps'],
        np.zeros_like(licking_sample['timestamps']),
        marker = 'o',
        color = 'black',
        linestyle = 'none'
    )
    
def plot_rewards(ax, ti, tf):
    rewards_sample = dataset.rewards.query('timestamps >= @ti and timestamps <= @tf')
    ax.plot(
        rewards_sample['timestamps'],
        np.zeros_like(rewards_sample['timestamps']),
        marker = 'd',
        color = 'blue',
        linestyle = 'none',
        markersize = 12,
        alpha = 0.5
    )
    
def plot_stimuli(ax, ti, tf):
    stimulus_presentations_sample = dataset.stimulus_presentations.query('stop_time >= @ti and start_time <= @tf')
    for idx, stimulus in stimulus_presentations_sample.iterrows():
        ax.axvspan(stimulus['start_time'], stimulus['stop_time'], color=stimulus['color'], alpha=0.25)

# %% [markdown]
# #### now make the plot
# Notes:
# * We can see two stimulus change in this period
# * The mouse licked immediately following both changes, resulting in reward

# %%
ti = 775
tf = 800
fig, ax = plt.subplots(figsize = (15,5))
plot_running(ax, ti, tf)
plot_licks(ax, ti, tf)
plot_rewards(ax, ti, tf)
plot_stimuli(ax, ti, tf)

ax.legend(['running speed', 'licks', 'rewards'])

ax.set_ylabel('running speed (cm/s)')
ax.set_xlabel('time in session (s)')
ax.set_xlim(ti, tf)
ax.set_title('a short section of the session');
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# ### trials

# %%
dataset.trials.sample(5)
# Out:
#             start_time    stop_time  \
# trials_id
# 136        1159.321934  1166.611380
# 103         926.827004   936.368329
# 54          596.533372   606.074754
# 390        2857.662656  2867.220658
# 132        1136.736341  1145.560392
#
#                                                   lick_times  reward_time  \
# trials_id
# 136        [1162.7247860990465, 1162.8248630384915, 1162....  1162.724786
# 103        [932.4984204894863, 932.6652132915333, 932.915...   932.498420
# 54                                                        []          NaN
# 390                                                       []          NaN
# 132                 [1141.6738107153215, 1141.8406353001483]          NaN
#
#            reward_volume    hit  false_alarm   miss  stimulus_change  aborted  \
# trials_id
# 136                0.007   True        False  False             True    False
# 103                0.007   True        False  False             True    False
# 54                 0.000  False        False   True             True    False
# 390                0.000  False        False   True             True    False
# 132                0.000  False         True  False            False    False
#
#               go  catch  auto_rewarded  correct_reject  trial_length  \
# trials_id
# 136         True  False          False           False      7.289446
# 103         True  False          False           False      9.541325
# 54          True  False          False           False      9.541382
# 390         True  False          False           False      9.558003
# 132        False   True          False           False      8.824051
#
#            response_time  change_frame  change_time  response_latency  \
# trials_id
# 136          1162.724786       69681.0  1162.345610          0.379176
# 103           932.498420       55878.0   932.102557          0.395864
# 54                   NaN       36078.0   601.825656               inf
# 390                  NaN      171632.0  2862.954883               inf
# 132          1141.673811       68418.0  1141.277953          0.395857
#
#           initial_image_name change_image_name
# trials_id
# 136                    im063             im062
# 103                    im069             im061
# 54                     im065             im066
# 390                    im063             im066
# 132                    im065             im065

# %% [markdown]
# #### we can examine one trial in some detail. Let's randomly select a hit trial.
# Some things to note:
# * the stimulus changed from 'im063' (`intial_image_name`) to 'im069' (`change_image_name`) at t = 834.287206646593 seconds (`change_time`) relative to the start of the session
# * the animal's first lick (`lick_times[0]`) and `response_time` was at t = 834.69975263 seconds relative to the start of the session
# * the `response_latency`, which is `response_time` - `change_time`, was 0.41254598174464263 seconds
# * a reward (`reward_time`) was delivered at 834.6997526283376 seconds relative to the start of the session. This was coincident with the first lick.

# %%
dataset.trials.query('hit').sample(random_state=0).to_dict('records')
# Out:
# [{'start_time': 831.2635398912244,
#   'stop_time': 838.5529783256352,
#   'lick_times': array([834.69975263, 834.81651755, 835.1001309 , 835.25021287,
#          835.40033855, 835.53378616, 835.68391515, 835.83403254,
#          836.01752922, 836.16765357, 836.33444306, 836.51795332,
#          836.6513857 ]),
#   'reward_time': 834.6997526283376,
#   'reward_volume': 0.007,
#   'hit': True,
#   'false_alarm': False,
#   'miss': False,
#   'stimulus_change': True,
#   'aborted': False,
#   'go': True,
#   'catch': False,
#   'auto_rewarded': False,
#   'correct_reject': False,
#   'trial_length': 7.28943843441084,
#   'response_time': 834.6997526283376,
#   'change_frame': 50014.0,
#   'change_time': 834.287206646593,
#   'response_latency': 0.41254598174464263,
#   'initial_image_name': 'im063',
#   'change_image_name': 'im069'}]

# %% [markdown]
# ## One useful method is the `get_performance_metrics` method, which returns some summary metrics on the session, derived from the 'rolling_performance_df'

# %%
behavior_session_dict[behavior_session_ids[-1]].get_performance_metrics()
# Out:
# {'trial_count': 406,
#  'go_trial_count': 355,
#  'catch_trial_count': 51,
#  'hit_trial_count': 0,
#  'miss_trial_count': 355,
#  'false_alarm_trial_count': 0,
#  'correct_reject_trial_count': 51,
#  'auto_rewarded_trial_count': 0,
#  'rewarded_trial_count': 0,
#  'total_reward_count': 0,
#  'total_reward_volume': 0.0,
#  'maximum_reward_rate': 0.0,
#  'engaged_trial_count': 0,
#  'mean_hit_rate': 0.011875913478097595,
#  'mean_hit_rate_uncorrected': 0.0,
#  'mean_hit_rate_engaged': nan,
#  'mean_false_alarm_rate': 0.057625554794490434,
#  'mean_false_alarm_rate_uncorrected': 0.0,
#  'mean_false_alarm_rate_engaged': nan,
#  'mean_dprime': -0.6347800516507073,
#  'mean_dprime_engaged': nan,
#  'max_dprime': -0.4636160066191892,
#  'max_dprime_engaged': nan}

# %% [markdown]
# ## we can build out a new table that has all performance data for every session as follows:

# %%
behavior_performance_table = pd.DataFrame(
    [behavior_session_dict[behavior_session_id].get_performance_metrics() for behavior_session_id in behavior_session_ids]
).set_index(behavior_session_ids)

# %%
behavior_performance_table.head()
# Out:
#            trial_count  go_trial_count  catch_trial_count  hit_trial_count  \
# 837658854          118               0                  0                0
# 838515247         1405             133                 13              106
# 839219841          451             335                 61               48
# 839565422          683             269                 41              107
# 839912316          966             174                 20              103
#
#            miss_trial_count  false_alarm_trial_count  \
# 837658854                 0                        0
# 838515247                27                        6
# 839219841               287                        1
# 839565422               162                        4
# 839912316                71                        6
#
#            correct_reject_trial_count  auto_rewarded_trial_count  \
# 837658854                           0                        118
# 838515247                           7                          5
# 839219841                          60                         29
# 839565422                          37                         15
# 839912316                          14                         10
#
#            rewarded_trial_count  total_reward_count  total_reward_volume  \
# 837658854                   118                 118                0.590
# 838515247                   111                 111                1.085
# 839219841                    77                  77                0.625
# 839565422                   122                 122                1.145
# 839912316                   113                 113                1.080
#
#            maximum_reward_rate  engaged_trial_count  mean_hit_rate  \
# 837658854             4.852157                  101            NaN
# 838515247             5.294545                  346       0.808946
# 839219841             5.015095                   49       0.231115
# 839565422             5.393113                  403       0.523621
# 839912316             3.833645                  583       0.778670
#
#            mean_hit_rate_uncorrected  mean_hit_rate_engaged  \
# 837658854                        NaN                    NaN
# 838515247                   0.819726               0.822212
# 839219841                   0.233778               0.809956
# 839565422                   0.529213               0.877314
# 839912316                   0.785813               0.919466
#
#            mean_false_alarm_rate  mean_false_alarm_rate_uncorrected  \
# 837658854                    NaN                                NaN
# 838515247               0.574381                           0.624039
# 839219841               0.059502                           0.025165
# 839565422               0.192331                           0.169870
# 839912316               0.439618                           0.511879
#
#            mean_false_alarm_rate_engaged  mean_dprime  mean_dprime_engaged  \
# 837658854                            NaN          NaN                  NaN
# 838515247                       0.421906     0.662053             1.145407
# 839219841                       0.176463     0.452645             1.875796
# 839565422                       0.377171     1.208391             1.599180
# 839912316                       0.586558     1.164035             1.240594
#
#            max_dprime  max_dprime_engaged
# 837658854         NaN                 NaN
# 838515247    1.832280            1.832280
# 839219841    2.288211            2.288211
# 839565422    2.201408            2.201408
# 839912316    1.679661            1.644854

# %% [markdown]
# ## for convenience, we should merge this with the existing table we built for this mouse

# %%
this_mouse_table = this_mouse_table.merge(
    behavior_performance_table,
    left_index = True,
    right_index = True,
)
this_mouse_table.head()
# Out:
#                     equipment_name  \
# behavior_session_id
# 837658854               BEH.B-Box3
# 838515247               BEH.B-Box1
# 839219841               BEH.B-Box1
# 839565422               BEH.B-Box1
# 839912316               BEH.B-Box1
#
#                                                          full_genotype  \
# behavior_session_id
# 837658854            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 838515247            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839219841            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839565422            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839912316            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
#
#                      mouse_id       reporter_line  \
# behavior_session_id
# 837658854              445002  Ai93(TITL-GCaMP6f)
# 838515247              445002  Ai93(TITL-GCaMP6f)
# 839219841              445002  Ai93(TITL-GCaMP6f)
# 839565422              445002  Ai93(TITL-GCaMP6f)
# 839912316              445002  Ai93(TITL-GCaMP6f)
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 837658854            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         72.0
# 838515247            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         75.0
# 839219841            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         76.0
# 839565422            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         77.0
# 839912316            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         78.0
#
#                                               session_type           cre_line  \
# behavior_session_id
# 837658854            TRAINING_0_gratings_autorewards_15min  Slc17a7-IRES2-Cre
# 838515247                              TRAINING_1_gratings  Slc17a7-IRES2-Cre
# 839219841                              TRAINING_1_gratings  Slc17a7-IRES2-Cre
# 839565422                              TRAINING_1_gratings  Slc17a7-IRES2-Cre
# 839912316                      TRAINING_2_gratings_flashed  Slc17a7-IRES2-Cre
#
#                     indicator  session_number  \
# behavior_session_id
# 837658854             GCaMP6f             NaN
# 838515247             GCaMP6f             NaN
# 839219841             GCaMP6f             NaN
# 839565422             GCaMP6f             NaN
# 839912316             GCaMP6f             NaN
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 837658854                                          0
# 838515247                                          0
# 839219841                                          1
# 839565422                                          2
# 839912316                                          0
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 837658854                                     NaN
# 838515247                                     NaN
# 839219841                                     NaN
# 839565422                                     NaN
# 839912316                                     NaN
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# behavior_session_id
# 837658854                                       0               NaN
# 838515247                                       0               NaN
# 839219841                                       0               NaN
# 839565422                                       0               NaN
# 839912316                                       0               NaN
#
#                     ophys_experiment_id ophys_container_id project_code  \
# behavior_session_id
# 837658854                           NaN                NaN          NaN
# 838515247                           NaN                NaN          NaN
# 839219841                           NaN                NaN          NaN
# 839565422                           NaN                NaN          NaN
# 839912316                           NaN                NaN          NaN
#
#                          date_of_acquisition       file_id  trial_count  \
# behavior_session_id
# 837658854            2019-03-15 14:49:24.015  1.085362e+09          118
# 838515247            2019-03-18 13:44:01.474  1.085362e+09         1405
# 839219841            2019-03-19 12:50:12.068  1.085362e+09          451
# 839565422            2019-03-20 13:16:44.461  1.085362e+09          683
# 839912316            2019-03-21 12:54:25.388  1.081589e+09          966
#
#                      go_trial_count  catch_trial_count  hit_trial_count  \
# behavior_session_id
# 837658854                         0                  0                0
# 838515247                       133                 13              106
# 839219841                       335                 61               48
# 839565422                       269                 41              107
# 839912316                       174                 20              103
#
#                      miss_trial_count  false_alarm_trial_count  \
# behavior_session_id
# 837658854                           0                        0
# 838515247                          27                        6
# 839219841                         287                        1
# 839565422                         162                        4
# 839912316                          71                        6
#
#                      correct_reject_trial_count  auto_rewarded_trial_count  \
# behavior_session_id
# 837658854                                     0                        118
# 838515247                                     7                          5
# 839219841                                    60                         29
# 839565422                                    37                         15
# 839912316                                    14                         10
#
#                      rewarded_trial_count  total_reward_count  \
# behavior_session_id
# 837658854                             118                 118
# 838515247                             111                 111
# 839219841                              77                  77
# 839565422                             122                 122
# 839912316                             113                 113
#
#                      total_reward_volume  maximum_reward_rate  \
# behavior_session_id
# 837658854                          0.590             4.852157
# 838515247                          1.085             5.294545
# 839219841                          0.625             5.015095
# 839565422                          1.145             5.393113
# 839912316                          1.080             3.833645
#
#                      engaged_trial_count  mean_hit_rate  \
# behavior_session_id
# 837658854                            101            NaN
# 838515247                            346       0.808946
# 839219841                             49       0.231115
# 839565422                            403       0.523621
# 839912316                            583       0.778670
#
#                      mean_hit_rate_uncorrected  mean_hit_rate_engaged  \
# behavior_session_id
# 837658854                                  NaN                    NaN
# 838515247                             0.819726               0.822212
# 839219841                             0.233778               0.809956
# 839565422                             0.529213               0.877314
# 839912316                             0.785813               0.919466
#
#                      mean_false_alarm_rate  mean_false_alarm_rate_uncorrected  \
# behavior_session_id
# 837658854                              NaN                                NaN
# 838515247                         0.574381                           0.624039
# 839219841                         0.059502                           0.025165
# 839565422                         0.192331                           0.169870
# 839912316                         0.439618                           0.511879
#
#                      mean_false_alarm_rate_engaged  mean_dprime  \
# behavior_session_id
# 837658854                                      NaN          NaN
# 838515247                                 0.421906     0.662053
# 839219841                                 0.176463     0.452645
# 839565422                                 0.377171     1.208391
# 839912316                                 0.586558     1.164035
#
#                      mean_dprime_engaged  max_dprime  max_dprime_engaged
# behavior_session_id
# 837658854                            NaN         NaN                 NaN
# 838515247                       1.145407    1.832280            1.832280
# 839219841                       1.875796    2.288211            2.288211
# 839565422                       1.599180    2.201408            2.201408
# 839912316                       1.240594    1.679661            1.644854

# %% [markdown]
# ## Remove negative d' values for for passive sessions
# One issue with the way that d' is calculated is that it relies on the rolling hit and false alarm rates, but applies a correction to each that avoids letting their values approach 0 or 1 for low trial counts. In fact, they can only be uniquely 0 or 1 for infinite trial counts, which we of course never have. See a discussion here:
# https://github.com/AllenInstitute/AllenSDK/blob/master/allensdk/brain_observatory/behavior/dprime_readme.md
#
# Thus, the rolling hit and false alarm rates are not 0 in passive sessions, even though the animal is not responding by default. In addition, because the task design has inbalanced go/catch trials, the false alarm rate is generally more restricted by this trial count limit. This leads to a negative d' value.
#
# Since this really doesn't make sense, we'll just set mean_dprime and max_dprime to 0 here

# %%
passive_sessions = this_mouse_table[this_mouse_table['session_type'].str.contains('passive')]
this_mouse_table.at[passive_sessions.index, 'max_dprime'] = 0
this_mouse_table.at[passive_sessions.index, 'mean_dprime'] = 0

# %% [markdown]
# ## Now we can plot the `max_dprime` value for every session

# %%
fig, ax = plt.subplots(figsize = (15,5))

ax.plot(
    np.arange(len(this_mouse_table)),
    this_mouse_table['max_dprime'],
    marker = 'o'
)
ax.set_xticks(range(len(this_mouse_table)))
ax.set_xticklabels(list(this_mouse_table['session_type'].values),rotation = 30, ha='right')

# make alternating black/gray vspans for visual clarity
colors = ['black', 'gray']
for ii in range(len(this_mouse_table)):
    ax.axvspan(ii - 0.5, ii + 0.5, color = colors[ii%2], alpha=0.25)

ax.set_xlim(-0.5, len(this_mouse_table) - 0.5)
ax.set_ylabel('dprime')
ax.set_title("Max of rolling d' for every session for mouse {}".format(mouse_id))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1500">
