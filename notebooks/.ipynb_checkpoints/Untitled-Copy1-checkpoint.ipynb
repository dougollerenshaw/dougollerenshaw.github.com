# %%
import allensdk.brain_observatory.behavior.behavior_project_cache as bpc
import pandas as pd

my_cache_dir = '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/allensdk_visualbehavior_cache'

bc = bpc.VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=my_cache_dir)

bs1 = bc.get_behavior_session(870987812)
          
behavior_session_table = bc.get_behavior_session_table()  

mouse_id = 445002

this_mouse_table = behavior_session_table.query('mouse_id == @mouse_id').sort_values(by = 'date_of_acquisition')

cols_to_show = [
    'mouse_id',
    'date_of_acquisition',
    'session_type',
    'prior_exposures_to_session_type', 
    'prior_exposures_to_image_set'
]
this_mouse_table[cols_to_show]
# Out:
#                      mouse_id      date_of_acquisition  \
# behavior_session_id
# 837658854              445002  2019-03-15 14:49:24.015
# 838515247              445002  2019-03-18 13:44:01.474
# 839219841              445002  2019-03-19 12:50:12.068
# 839565422              445002  2019-03-20 13:16:44.461
# 839912316              445002  2019-03-21 12:54:25.388
# 840581827              445002  2019-03-22 12:56:37.162
# 841426832              445002  2019-03-25 13:33:53.275
# 841827774              445002  2019-03-26 12:43:01.470
# 842385277              445002  2019-03-27 12:13:04.923
# 842819933              445002  2019-03-28 12:11:36.413
# 843400453              445002  2019-03-29 13:03:16.029
# 844199758              445002  2019-04-01 11:59:06.026
# 844908261              445002  2019-04-02 12:34:16.170
# 845572044              445002  2019-04-03 12:16:13.522
# 846331423              445002  2019-04-04 13:13:13.399
# 847036328              445002  2019-04-05 12:47:32.422
# 847874940              445002  2019-04-08 13:27:21.095
# 848613406              445002  2019-04-09 13:26:26.372
# 849147676              445002  2019-04-10 13:34:39.264
# 849651275              445002  2019-04-11 12:31:50.074
# 850989832              445002  2019-04-12 13:30:27.946
# 851773928              445002  2019-04-15 12:20:00.123
# 852451567              445002  2019-04-16 12:24:46.804
# 855200229              445002  2019-04-22 09:01:33.022
#
#                                               session_type  \
# behavior_session_id
# 837658854            TRAINING_0_gratings_autorewards_15min
# 838515247                              TRAINING_1_gratings
# 839219841                              TRAINING_1_gratings
# 839565422                              TRAINING_1_gratings
# 839912316                      TRAINING_2_gratings_flashed
# 840581827                      TRAINING_2_gratings_flashed
# 841426832                  TRAINING_3_images_A_10uL_reward
# 841827774                  TRAINING_3_images_A_10uL_reward
# 842385277                  TRAINING_3_images_A_10uL_reward
# 842819933                     TRAINING_4_images_A_training
# 843400453                     TRAINING_5_images_A_epilogue
# 844199758                TRAINING_5_images_A_handoff_ready
# 844908261                TRAINING_5_images_A_handoff_ready
# 845572044                TRAINING_5_images_A_handoff_ready
# 846331423                     OPHYS_0_images_A_habituation
# 847036328                     OPHYS_0_images_A_habituation
# 847874940                     OPHYS_0_images_A_habituation
# 848613406                                 OPHYS_1_images_A
# 849147676                         OPHYS_2_images_A_passive
# 849651275                                 OPHYS_3_images_A
# 850989832                                 OPHYS_4_images_B
# 851773928                         OPHYS_5_images_B_passive
# 852451567                                 OPHYS_6_images_B
# 855200229                         OPHYS_5_images_B_passive
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 837658854                                          0
# 838515247                                          0
# 839219841                                          1
# 839565422                                          2
# 839912316                                          0
# 840581827                                          1
# 841426832                                          0
# 841827774                                          1
# 842385277                                          2
# 842819933                                          0
# 843400453                                          0
# 844199758                                          0
# 844908261                                          1
# 845572044                                          2
# 846331423                                          0
# 847036328                                          1
# 847874940                                          2
# 848613406                                          0
# 849147676                                          0
# 849651275                                          0
# 850989832                                          0
# 851773928                                          0
# 852451567                                          0
# 855200229                                          1
#
#                      prior_exposures_to_image_set
# behavior_session_id
# 837658854                                     NaN
# 838515247                                     NaN
# 839219841                                     NaN
# 839565422                                     NaN
# 839912316                                     NaN
# 840581827                                     NaN
# 841426832                                     NaN
# 841827774                                     NaN
# 842385277                                     NaN
# 842819933                                     NaN
# 843400453                                     NaN
# 844199758                                     NaN
# 844908261                                     NaN
# 845572044                                     NaN
# 846331423                                     0.0
# 847036328                                     1.0
# 847874940                                     2.0
# 848613406                                     3.0
# 849147676                                     4.0
# 849651275                                     5.0
# 850989832                                     0.0
# 851773928                                     1.0
# 852451567                                     2.0
# 855200229                                     3.0

# %%
ophys_session_table = bc.get_ophys_session_table()    
this_mouse_ophys_table = ophys_session_table.query('mouse_id == @mouse_id').sort_values(by = 'date_of_acquisition')

this_mouse_ophys_table[cols_to_show]
# Out:
#                   mouse_id         date_of_acquisition  \
# ophys_session_id
# 848264483           445002  2019-04-09 17:15:25.000000
# 848894137           445002  2019-04-10 16:46:31.000000
# 849597937           445002  2019-04-11 18:56:20.000000
# 850959102           445002  2019-04-12 19:52:29.000000
# 852326785           445002  2019-04-16 18:52:04.000000
# 855083235           445002  2019-04-22 14:29:07.000000
#
#                               session_type  prior_exposures_to_session_type  \
# ophys_session_id
# 848264483                 OPHYS_1_images_A                                0
# 848894137         OPHYS_2_images_A_passive                                0
# 849597937                 OPHYS_3_images_A                                0
# 850959102                 OPHYS_4_images_B                                0
# 852326785                 OPHYS_6_images_B                                0
# 855083235         OPHYS_5_images_B_passive                                1
#
#                   prior_exposures_to_image_set
# ophys_session_id
# 848264483                                  3.0
# 848894137                                  4.0
# 849597937                                  5.0
# 850959102                                  0.0
# 852326785                                  2.0
# 855083235                                  3.0

# %%
dir(bc)
# Out:
# ['BEHAVIOR_SESSIONS_KEY',
#  'MANIFEST_CONFIG',
#  'MANIFEST_VERSION',
#  'OPHYS_EXPERIMENTS_KEY',
#  'OPHYS_SESSIONS_KEY',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_log',
#  'add_manifest_paths',
#  'build_manifest',
#  'cache',
#  'cache_csv',
#  'cache_csv_dataframe',
#  'cache_csv_json',
#  'cache_json',
#  'cache_json_dataframe',
#  'cacher',
#  'csv_writer',
#  'fetch_api',
#  'fetch_tries',
#  'from_lims',
#  'from_local_cache',
#  'from_s3_cache',
#  'get_behavior_ophys_experiment',
#  'get_behavior_session',
#  'get_behavior_session_table',
#  'get_cache_path',
#  'get_ophys_experiment_table',
#  'get_ophys_session_table',
#  'json_remove_keys',
#  'json_rename_columns',
#  'load_csv',
#  'load_json',
#  'load_manifest',
#  'logger',
#  'manifest',
#  'manifest_dataframe',
#  'manifest_path',
#  'nocache_dataframe',
#  'nocache_json',
#  'pathfinder',
#  'remove_keys',
#  'rename_columns',
#  'wrap']

# %%
bs1 = bc.get_behavior_session(870987812)
# Out:
# behavior_session_870987812.nwb: 100%|██████████| 51.7M/51.7M [00:04<00:00, 12.4MMB/s]
